# %%
class Income:
    
    def __init__(self):
        self.sources_of_income = []
        self.total_income = 0


    def rental_income(self):
        ask_rental_income = int(input("How much money do you recieve from rental income? "))
        self.sources_of_income.append(ask_rental_income)
        self.laundry_income()

    def laundry_income(self):
        ask_laundry_income = int(input("How much money -if any- do you recieve from laundry? "))
        self.sources_of_income.append(ask_laundry_income)
        self.storage_income()

    def storage_income(self):
        ask_storage_income = int(input("How much money -if any- do you recieve from storage? "))
        self.sources_of_income.append(ask_storage_income)
        self.misc_income()

    def misc_income(self):
        ask_misc_income = int(input("How much money -if any- do you recieve from misc? "))
        self.sources_of_income.append(ask_misc_income)
        self.get_income()

    def get_income(self):
        self.total_income = sum(self.sources_of_income)
        self.print_total_income()


    def print_total_income(self):
        print(f"Thanks for inputing that information. Looks like your total monthly income from this rental property is ${self.total_income}.")
        
    

class Expenses: 
    
    def __init__(self): 
        self.expense = []
        self.total_expenses = 0
        
    def tax_expense(self):
        ask_tax_expense = int(input("What is the total cost for your taxes? "))
        self.expense.append(ask_tax_expense)
        self.insurance_expense()
    
    def insurance_expense(self):
        ask_insurance_expense = int(input("What is the total cost for your insurance? "))
        self.expense.append(ask_insurance_expense)
        self.utilities_expense()
        
    def utilities_expense(self): 
        ask_utlities_expense = int(input("What is the total cost for your utilities? This includes water/sewage/gas/electric/garbage "))
        self.expense.append(ask_utlities_expense)
        self.hoa_expense()
        
    def hoa_expense(self):
        ask_hoa_expense = int(input("What is the total cost -if any- for your HOA expense? "))
        self.expense.append(ask_hoa_expense)
        self.vacancy_expense()
    
    def vacancy_expense(self):
        ask_vacancy_expense = int(input("What is the total cost -if any- for your vacany expense? "))
        self.expense.append(ask_vacancy_expense)
        self.repairs_expense()
    
    def repairs_expense(self):
        ask_repairs_expense = int(input("What is the total cost -if any- for your repairs expense? "))
        self.expense.append(ask_repairs_expense)
        self.property_management_expense()
    
    def property_management_expense(self):
        ask_property_management_expense = int(input("What is the total cost -if any- for your property management expense? "))
        self.expense.append(ask_property_management_expense)
        self.mortage_expense()
    
    def mortage_expense(self):
        ask_mortage_expense = int(input("What is the total cost -if any- for your mortage expense? "))
        self.expense.append(ask_mortage_expense)
        self.get_expenses()
        
    def get_expenses(self):
        self.total_expenses = sum(self.expense)
        self.print_total_expenses()
            
        
    def print_total_expenses(self):
        print(f"Thanks for inputing that information. Looks like your total monthly expenses from this rental property is ${self.total_expenses}")
        
    
    
class Cash_flow:
    
    def _init_(self, total_income, total_expenses):
        self.total_income = total_income
        self.total_expenses = total_expenses
        self.monthly_cash_flow = 0 
        self.yearly_cash_flow = 0
        
        
    def get_monthly(self):
        self.monthly_cash_flow = {self.total_income} - {self.total_expenses}
        
    def get_yearly(self):
        self.yearly_cash_flow = monthly_cash_flow *12
        
    def print_cash_flow(self):
        print(f"Looks like your monthly cash flow is {self.monthly_cash_flow}, meaning that your yearly cash flow from this rental property is {self.yearly_cash_flow}. Now let's divide this by your total investment to find out your ROI!" )
        
        
    
class ROI: 
    
    def __init__(self, yearly_cash_flow, monthly_cash_flow): 
        self.yearly_cash_flow = yearly_cash_flow
        self.mothly_cash_flow = monthly_cash_flow
        self.roi = 0
        self.total_investment = []
        
    
    def downpayment(self):
        ask_initial_investment = int(input("How much money was the downpayment? "))
        self.total_investment.append()
        
    def closing_costs(self):
        ask_initial_investment = int(input("How much money was the downpayment? "))
        self.total_investment.append()
    
    def rehab_budget(self):
        ask_initial_investment = int(input("How much money was the downpayment? "))
        self.total_investment.append()
        
    
    def misc(self): 
        ask_initial_investment = int(input("How much money was the downpayment? "))
        self.total_investment.append()
    
    def get_roi(self, yearly_cash_flow):
        self.roi = {self.yearly_cash_flow} // {self.total_investment}
        
    
    def print_roi(self):
        print(f"Your Cash on Cash ROI is {roi}")
        
        
def main():
    
    print("""
    Welcome to the ROI calculator! This tool will help you calculate the cash on cash return on investment for a rental property. Please exclude commas, decimals, or dollar signs from your numerical inputs."
    
    """)
    
    income = Income() 
    income.rental_income()
    expense = Expenses()
    expense.tax_expense()
    
    
    
    
    
    
    option = {'q'}
    
    user_active = True
    while user_active == True: 
        if option == 'q':
            print("Thanks for using the ROI calculator. Come back soon!")
            user_active = False 
            break
        
main()
# Out:
#     Welcome to the ROI calculator! This tool will help you calculate the cash on cash return on investment for a rental property. Please exclude commas, decimals, or dollar signs from your numerical inputs."
#
#
# How much money do you recieve from rental income? 2
# How much money -if any- do you recieve from laundry? 2
# How much money -if any- do you recieve from storage? 2
# How much money -if any- do you recieve from misc? 2
# Thanks for inputing that information. Looks like your total monthly income from this rental property is $8.
# What is the total cost for your taxes? 2
# What is the total cost for your insurance? 2
# What is the total cost for your utilities? This includes water/sewage/gas/electric/garbage 2
# What is the total cost -if any- for your HOA expense? 2
# What is the total cost -if any- for your vacany expense? 2
# What is the total cost -if any- for your repairs expense? 2
# What is the total cost -if any- for your property management expense? 2
# ...
